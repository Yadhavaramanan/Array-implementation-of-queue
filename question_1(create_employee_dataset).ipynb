# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadhavaramanan/Array-implementation-of-queue/blob/main/question_1(create_employee_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create the employee dataset
data = {
    'Name': ['John', 'Alice', 'Bob', 'Emily', 'Michael'],
    'Employee ID': [101, 102, 103, 104, 105],
    'Age': [30, 25, 35, None, 40],  # Adding a missing value for demonstration
    'Salary': [50000, 60000, 55000, 70000, 65000],
    'Department': ['HR', 'Finance', 'IT', 'IT', 'Marketing']
}

# %%
data
# Out:
# {'Name': ['John', 'Alice', 'Bob', 'Emily', 'Michael'],
#  'Employee ID': [101, 102, 103, 104, 105],
#  'Age': [30, 25, 35, None, 40],
#  'Salary': [50000, 60000, 55000, 70000, 65000],
#  'Department': ['HR', 'Finance', 'IT', 'IT', 'Marketing']}

# %%
df = pd.DataFrame(data)

# %%
# Display the original dataset
print("Original Dataset:")
print(df)
print()
# Out:
# Original Dataset:
#       Name  Employee ID   Age  Salary Department
# 0     John          101  30.0   50000         HR
# 1    Alice          102  25.0   60000    Finance
# 2      Bob          103  35.0   55000         IT
# 3    Emily          104   NaN   70000         IT
# 4  Michael          105  40.0   65000  Marketing

# %%
# Data cleaning process
# Handling missing values
df['Age']
# Out:
# 0    30.0
# 1    25.0
# 2    35.0
# 3    32.5
# 4    40.0
# Name: Age, dtype: float64

# %%
# Data cleaning process
# Handling missing values
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
# Visualize the growth of each employee using a bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Salary'])
plt.xlabel('Employee')
plt.ylabel('Salary')
plt.title('Salary Growth of Each Employee')
plt.xticks(rotation=45)
plt.show()
